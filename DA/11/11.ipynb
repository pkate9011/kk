# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
# Creating the dataset
dataset = [['butter', 'bread', 'milk'], ['butter', 'flour', 'milk', 'sugar'], ['butter', 'eggs', 'milk', 'salt'],['eggs'], ['butter', 'flour', 'milk', 'salt']]
df = pd.DataFrame(dataset)
# Converting the categorical values into numeric format
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)
# Generating frequent itemsets using Apriori algorithm with different min_sup values
min_sup_values = [0.4, 0.3, 0.2]
for min_sup in min_sup_values:
    frequent_itemsets = apriori(df, min_support=min_sup, use_colnames=True)
    print("Frequent Itemsets with minimum support of", min_sup)
    print(frequent_itemsets)
# Generating association rules
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)
print("Association Rules with minimum support of", min_sup)
print(rules)
# Out:
# Frequent Itemsets with minimum support of 0.4
#     support               itemsets
# 0       0.8               (butter)
# 1       0.4                 (eggs)
# 2       0.4                (flour)
# 3       0.8                 (milk)
# 4       0.4                 (salt)
# 5       0.4        (flour, butter)
# 6       0.8         (milk, butter)
# 7       0.4         (salt, butter)
# 8       0.4          (milk, flour)
# 9       0.4           (milk, salt)
# 10      0.4  (milk, flour, butter)
# 11      0.4   (milk, salt, butter)
# Frequent Itemsets with minimum support of 0.3
#     support               itemsets
# 0       0.8               (butter)
# 1       0.4                 (eggs)
# 2       0.4                (flour)
# 3       0.8                 (milk)
# 4       0.4                 (salt)
# 5       0.4        (flour, butter)
# 6       0.8         (milk, butter)
# 7       0.4         (salt, butter)
# 8       0.4          (milk, flour)
# 9       0.4           (milk, salt)
# 10      0.4  (milk, flour, butter)
# 11      0.4   (milk, salt, butter)
# Frequent Itemsets with minimum support of 0.2
#     support                      itemsets
# 0       0.2                       (bread)
# 1       0.8                      (butter)
# 2       0.4                        (eggs)
# 3       0.4                       (flour)
# 4       0.8                        (milk)
# 5       0.4                        (salt)
# 6       0.2                       (sugar)
# 7       0.2               (bread, butter)
# 8       0.2                 (bread, milk)
# 9       0.2                (eggs, butter)
# 10      0.4               (flour, butter)
# 11      0.8                (milk, butter)
# 12      0.4                (salt, butter)
# 13      0.2               (sugar, butter)
# 14      0.2                  (milk, eggs)
# 15      0.2                  (salt, eggs)
# 16      0.4                 (milk, flour)
# 17      0.2                 (flour, salt)
# 18      0.2                (sugar, flour)
# 19      0.4                  (milk, salt)
# 20      0.2                 (sugar, milk)
# 21      0.2         (bread, milk, butter)
# 22      0.2          (milk, eggs, butter)
# 23      0.2          (salt, eggs, butter)
# 24      0.4         (milk, flour, butter)
# 25      0.2         (flour, salt, butter)
# 26      0.2        (sugar, flour, butter)
# 27      0.4          (milk, salt, butter)
# 28      0.2         (sugar, milk, butter)
# 29      0.2            (milk, salt, eggs)
# 30      0.2           (milk, flour, salt)
# 31      0.2          (sugar, milk, flour)
# 32      0.2    (milk, salt, eggs, butter)
# 33      0.2   (milk, flour, salt, butter)
# 34      0.2  (sugar, milk, flour, butter)
# Association Rules with minimum support of 0.2
#                antecedents            consequents  antecedent support  \
# 0                  (bread)               (butter)                 0.2
# 1                  (bread)                 (milk)                 0.2
# 2                  (flour)               (butter)                 0.4
# 3                   (milk)               (butter)                 0.8
# 4                 (butter)                 (milk)                 0.8
# 5                   (salt)               (butter)                 0.4
# 6                  (sugar)               (butter)                 0.2
# 7                  (flour)                 (milk)                 0.4
# 8                  (sugar)                (flour)                 0.2
# 9                   (salt)                 (milk)                 0.4
# 10                 (sugar)                 (milk)                 0.2
# 11           (bread, milk)               (butter)                 0.2
# 12         (bread, butter)                 (milk)                 0.2
# 13                 (bread)         (milk, butter)                 0.2
# 14            (milk, eggs)               (butter)                 0.2
# 15          (eggs, butter)                 (milk)                 0.2
# 16            (salt, eggs)               (butter)                 0.2
# 17          (eggs, butter)                 (salt)                 0.2
# 18           (milk, flour)               (butter)                 0.4
# 19         (flour, butter)                 (milk)                 0.4
# 20                 (flour)         (milk, butter)                 0.4
# 21           (flour, salt)               (butter)                 0.2
# 22          (sugar, flour)               (butter)                 0.2
# 23         (sugar, butter)                (flour)                 0.2
# 24                 (sugar)        (flour, butter)                 0.2
# 25            (milk, salt)               (butter)                 0.4
# 26          (salt, butter)                 (milk)                 0.4
# 27                  (salt)         (milk, butter)                 0.4
# 28           (sugar, milk)               (butter)                 0.2
# 29         (sugar, butter)                 (milk)                 0.2
# 30                 (sugar)         (milk, butter)                 0.2
# 31            (milk, eggs)                 (salt)                 0.2
# 32            (salt, eggs)                 (milk)                 0.2
# 33           (flour, salt)                 (milk)                 0.2
# 34           (sugar, milk)                (flour)                 0.2
# 35          (sugar, flour)                 (milk)                 0.2
# 36                 (sugar)          (milk, flour)                 0.2
# 37      (milk, salt, eggs)               (butter)                 0.2
# 38    (milk, eggs, butter)                 (salt)                 0.2
# 39    (salt, eggs, butter)                 (milk)                 0.2
# 40            (milk, eggs)         (salt, butter)                 0.2
# 41            (salt, eggs)         (milk, butter)                 0.2
# 42          (eggs, butter)           (milk, salt)                 0.2
# 43     (milk, flour, salt)               (butter)                 0.2
# 44   (flour, salt, butter)                 (milk)                 0.2
# 45           (flour, salt)         (milk, butter)                 0.2
# 46    (sugar, milk, flour)               (butter)                 0.2
# 47   (sugar, milk, butter)                (flour)                 0.2
# 48  (sugar, flour, butter)                 (milk)                 0.2
# 49           (sugar, milk)        (flour, butter)                 0.2
# 50          (sugar, flour)         (milk, butter)                 0.2
# 51         (sugar, butter)          (milk, flour)                 0.2
# 52                 (sugar)  (milk, flour, butter)                 0.2
#
#     consequent support  support  confidence  lift  leverage  conviction  \
# 0                  0.8      0.2         1.0  1.25      0.04         inf
# 1                  0.8      0.2         1.0  1.25      0.04         inf
# 2                  0.8      0.4         1.0  1.25      0.08         inf
# 3                  0.8      0.8         1.0  1.25      0.16         inf
# 4                  0.8      0.8         1.0  1.25      0.16         inf
# 5                  0.8      0.4         1.0  1.25      0.08         inf
# 6                  0.8      0.2         1.0  1.25      0.04         inf
# 7                  0.8      0.4         1.0  1.25      0.08         inf
# 8                  0.4      0.2         1.0  2.50      0.12         inf
# 9                  0.8      0.4         1.0  1.25      0.08         inf
# 10                 0.8      0.2         1.0  1.25      0.04         inf
# 11                 0.8      0.2         1.0  1.25      0.04         inf
# 12                 0.8      0.2         1.0  1.25      0.04         inf
# 13                 0.8      0.2         1.0  1.25      0.04         inf
# 14                 0.8      0.2         1.0  1.25      0.04         inf
# 15                 0.8      0.2         1.0  1.25      0.04         inf
# 16                 0.8      0.2         1.0  1.25      0.04         inf
# 17                 0.4      0.2         1.0  2.50      0.12         inf
# 18                 0.8      0.4         1.0  1.25      0.08         inf
# 19                 0.8      0.4         1.0  1.25      0.08         inf
# 20                 0.8      0.4         1.0  1.25      0.08         inf
# 21                 0.8      0.2         1.0  1.25      0.04         inf
# 22                 0.8      0.2         1.0  1.25      0.04         inf
# 23                 0.4      0.2         1.0  2.50      0.12         inf
# 24                 0.4      0.2         1.0  2.50      0.12         inf
# 25                 0.8      0.4         1.0  1.25      0.08         inf
# 26                 0.8      0.4         1.0  1.25      0.08         inf
# 27                 0.8      0.4         1.0  1.25      0.08         inf
# 28                 0.8      0.2         1.0  1.25      0.04         inf
# 29                 0.8      0.2         1.0  1.25      0.04         inf
# 30                 0.8      0.2         1.0  1.25      0.04         inf
# 31                 0.4      0.2         1.0  2.50      0.12         inf
# 32                 0.8      0.2         1.0  1.25      0.04         inf
# 33                 0.8      0.2         1.0  1.25      0.04         inf
# 34                 0.4      0.2         1.0  2.50      0.12         inf
# 35                 0.8      0.2         1.0  1.25      0.04         inf
# 36                 0.4      0.2         1.0  2.50      0.12         inf
# 37                 0.8      0.2         1.0  1.25      0.04         inf
# 38                 0.4      0.2         1.0  2.50      0.12         inf
# 39                 0.8      0.2         1.0  1.25      0.04         inf
# 40                 0.4      0.2         1.0  2.50      0.12         inf
# 41                 0.8      0.2         1.0  1.25      0.04         inf
# 42                 0.4      0.2         1.0  2.50      0.12         inf
# 43                 0.8      0.2         1.0  1.25      0.04         inf
# 44                 0.8      0.2         1.0  1.25      0.04         inf
# 45                 0.8      0.2         1.0  1.25      0.04         inf
# 46                 0.8      0.2         1.0  1.25      0.04         inf
# 47                 0.4      0.2         1.0  2.50      0.12         inf
# 48                 0.8      0.2         1.0  1.25      0.04         inf
# 49                 0.4      0.2         1.0  2.50      0.12         inf
# 50                 0.8      0.2         1.0  1.25      0.04         inf
# 51                 0.4      0.2         1.0  2.50      0.12         inf
# 52                 0.4      0.2         1.0  2.50      0.12         inf
#
#     zhangs_metric
# 0        0.250000
# 1        0.250000
# 2        0.333333
# 3        1.000000
# 4        1.000000
# 5        0.333333
# 6        0.250000
# 7        0.333333
# 8        0.750000
# 9        0.333333
# 10       0.250000
# 11       0.250000
# 12       0.250000
# 13       0.250000
# 14       0.250000
# 15       0.250000
# 16       0.250000
# 17       0.750000
# 18       0.333333
# 19       0.333333
# 20       0.333333
# 21       0.250000
# 22       0.250000
# 23       0.750000
# 24       0.750000
# 25       0.333333
# 26       0.333333
# 27       0.333333
# 28       0.250000
# 29       0.250000
# 30       0.250000
# 31       0.750000
# 32       0.250000
# 33       0.250000
# 34       0.750000
# 35       0.250000
# 36       0.750000
# 37       0.250000
# 38       0.750000
# 39       0.250000
# 40       0.750000
# 41       0.250000
# 42       0.750000
# 43       0.250000
# 44       0.250000
# 45       0.250000
# 46       0.250000
# 47       0.750000
# 48       0.250000
# 49       0.750000
# 50       0.250000
# 51       0.750000
# 52       0.750000
